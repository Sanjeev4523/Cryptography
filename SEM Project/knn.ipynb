# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# ! pip install phe

# %%
# importing pallier
from phe import paillier

# %%
# initialisng Paillier
public_key, private_key = paillier.generate_paillier_keypair()
keyring = paillier.PaillierPrivateKeyring()
keyring.add(private_key)
public_key1, private_key1 = paillier.generate_paillier_keypair(keyring)
public_key2, private_key2 = paillier.generate_paillier_keypair(keyring)
print(f"Public Key 1:{public_key1}")
print(f"Private Key 1: {private_key1}")
# Out:
# Public Key 1:<PaillierPublicKey 6601649dae>
# Private Key 1: <PaillierPrivateKey for <PaillierPublicKey 6601649dae>>

# %%
# importing datasets and initialising Pandas dataframe
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/breast-cancer-wisconsin/breast-cancer-wisconsin.data"
names = ['id', 'clump_thickness', 'uniform_cell_size', 'uniform_cell_shape',
       'marginal_adhesion', 'single_epithelial_size', 'bare_nuclei',
       'bland_chromatin', 'normal_nucleoli', 'mitoses', 'class']
df = pd.read_csv(url, names=names)
df.head()
# Out:
#         id  clump_thickness  uniform_cell_size  uniform_cell_shape  \
# 0  1000025                5                  1                   1
# 1  1002945                5                  4                   4
# 2  1015425                3                  1                   1
# 3  1016277                6                  8                   8
# 4  1017023                4                  1                   1
#
#    marginal_adhesion  single_epithelial_size bare_nuclei  bland_chromatin  \
# 0                  1                       2           1                3
# 1                  5                       7          10                3
# 2                  1                       2           2                3
# 3                  1                       3           4                3
# 4                  3                       2           1                3
#
#    normal_nucleoli  mitoses  class
# 0                1        1      2
# 1                2        1      2
# ...

# %%
#preprocessing and cleaning data
df.replace('?',-99999, inplace=True)
df.drop(['id'], 1, inplace=True)
print(df.describe())
# Out:
#        clump_thickness  uniform_cell_size  uniform_cell_shape  \
# count       699.000000         699.000000          699.000000
# mean          4.417740           3.134478            3.207439
# std           2.815741           3.051459            2.971913
# min           1.000000           1.000000            1.000000
# 25%           2.000000           1.000000            1.000000
# 50%           4.000000           1.000000            1.000000
# 75%           6.000000           5.000000            5.000000
# max          10.000000          10.000000           10.000000
#
#        marginal_adhesion  single_epithelial_size  bland_chromatin  \
# count         699.000000              699.000000       699.000000
# mean            2.806867                3.216023         3.437768
# std             2.855379                2.214300         2.438364
# min             1.000000                1.000000         1.000000
# 25%             1.000000                2.000000         2.000000
# ...

# %%
df['encrypted_clump_thickness'] = [public_key.encrypt(x) for x in df['clump_thickness']]
df['encrypted_uniform_cell_size'] = [public_key.encrypt(x) for x in df['uniform_cell_size']]
df['encrypted_uniform_cell_shape'] = [public_key.encrypt(x) for x in df['uniform_cell_shape']]
df['encrypted_marginal_adhesion'] = [public_key.encrypt(x) for x in df['marginal_adhesion']]
df['encrypted_single_epithelial_size'] = [public_key.encrypt(int(x)) for x in df['single_epithelial_size']]
df['encrypted_bland_chromatin'] = [public_key.encrypt(x) for x in df['bland_chromatin']]
df['encrypted_normal_nucleoli'] = [public_key.encrypt(x) for x in df['normal_nucleoli']]
df['encrypted_mitoses'] = [public_key.encrypt(x) for x in df['mitoses']]
df['encrypted_class'] = [public_key.encrypt(x) for x in df['class']]
df['encrypted_bare_nuclei'] = [public_key.encrypt(int(x)) for x in df['bare_nuclei']]
#df['encrypted_'] = [public_key.encrypt(x) for x in df['']]

# %%
x.ciphertext()
# Out:
# ...

# %%
for i in range(0,698):
    df['encrypted_clump_thickness'][i] = df['encrypted_clump_thickness'][i].ciphertext()
    df['encrypted_uniform_cell_size'][i] = df['encrypted_uniform_cell_size'][i].ciphertext()
    df['encrypted_uniform_cell_shape'][i] = df['encrypted_uniform_cell_shape'][i].ciphertext()
    df['encrypted_marginal_adhesion'][i] = df['encrypted_marginal_adhesion'][i].ciphertext()
    df['encrypted_single_epithelial_size'][i] = df['encrypted_single_epithelial_size'][i].ciphertext()
    df['encrypted_bare_nuclei'][i] = df['encrypted_bare_nuclei'][i].ciphertext()
    df['encrypted_bland_chromatin'][i] = df['encrypted_bland_chromatin'][i].ciphertext()
    df['encrypted_normal_nucleoli'][i] = df['encrypted_normal_nucleoli'][i].ciphertext()
    df['encrypted_mitoses'][i] = df['encrypted_mitoses'][i].ciphertext()
    df['encrypted_bare_nuclei'][i] = df['encrypted_bare_nuclei'][i].ciphertext()
    df['encrypted_class'][i] = df['encrypted_class'][i].ciphertext()
    #df['encrypted_'][i] = df['encrypted_'][i].ciphertext()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-40-eab99e0ab769> in <module>
#       8     #df['encrypted_bland_chromatin'][i] = df['encrypted_bland_chromatin'][i].ciphertext()
#       9     #df['encrypted_normal_nucleoli'][i] = df['encrypted_normal_nucleoli'][i].ciphertext()
# ---> 10     df['encrypted_mitoses'][i] = df['encrypted_mitoses'][i].ciphertext()
#      11     df['encrypted_bare_nuclei'][i] = df['encrypted_bare_nuclei'][i].ciphertext()
#      12     df['encrypted_class'][i] = df['encrypted_class'][i].ciphertext()
#
# AttributeError: 'int' object has no attribute 'ciphertext'

# %%
df.head()
# Out:
#    clump_thickness  uniform_cell_size  uniform_cell_shape  marginal_adhesion  \
# 0                5                  1                   1                  1
# 1                5                  4                   4                  5
# 2                3                  1                   1                  1
# 3                6                  8                   8                  1
# 4                4                  1                   1                  3
#
#    single_epithelial_size bare_nuclei  bland_chromatin  normal_nucleoli  \
# 0                       2           1                3                1
# 1                       7          10                3                2
# 2                       2           2                3                1
# 3                       3           4                3                7
# 4                       2           1                3                1
#
# ...

# %%
df.to_csv('encrypted_csv.xlsx')

# %%
# Define models to train
models = []
models.append(('KNN', KNeighborsClassifier(n_neighbors = 5)))
models.append(('SVM', SVC()))

# evaluate each model in turn
results = []
names = []

for name, model in models:
    kfold = model_selection.KFold(n_splits=10, random_state = seed)
    cv_results = model_selection.cross_val_score(model, X_train, y_train, cv=kfold, scoring=scoring)
    results.append(cv_results)
    names.append(name)
    msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std())
    print(msg)
